# %% [markdown]
# # Choropleths
# * https://geopandas.org/en/stable/getting_started/introduction.html#
# * https://geopandas.org/en/stable/docs/user_guide/interactive_mapping.html

# %%
# Import numpy
import numpy as np

# Import geopandas & pandas
# # https://geopandas.org/en/stable/getting_started/install.html
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', None)


# Import matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Apply the default theme
sns.set_theme()

# ignore warnings on data imports
import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# # Plotting the world

# %%
#gpd.datasets.get_path('naturalearth_lowres')

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
type(world)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world.plot(
    column="continent", 
    legend=True, 
    figsize=(15, 15)
);

# %% [markdown]
# # Plotting Europe

# %%
europe = world[ world['continent'] == 'Europe' ]
europe
# Out:
#        pop_est continent              name iso_a3  gdp_md_est  \
# 18   142257519    Europe            Russia    RUS   3745000.0
# 21     5320045    Europe            Norway    -99    364700.0
# 43    67106161    Europe            France    -99   2699000.0
# 110    9960487    Europe            Sweden    SWE    498100.0
# 111    9549747    Europe           Belarus    BLR    165400.0
# 112   44033874    Europe           Ukraine    UKR    352600.0
# 113   38476269    Europe            Poland    POL   1052000.0
# 114    8754413    Europe           Austria    AUT    416600.0
# 115    9850845    Europe           Hungary    HUN    267600.0
# 116    3474121    Europe           Moldova    MDA     18540.0
# 117   21529967    Europe           Romania    ROU    441000.0
# 118    2823859    Europe         Lithuania    LTU     85620.0
# 119    1944643    Europe            Latvia    LVA     50650.0
# 120    1251581    Europe           Estonia    EST     38700.0
# ...

# %%
europe.plot(
    column="name", 
    figsize=(15, 15)
);

# %% [markdown]
# # Plotting Europe (sans Russia)

# %%
europe[ europe['name'] != 'Russia'].plot(
    column="name",
    figsize=(15, 15)
);

# %%
europe[ europe['name'] != 'Russia'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Plotting Africa

# %%
world['continent'].value_counts()
# Out:
# Africa                     51
# Asia                       47
# Europe                     39
# North America              18
# South America              13
# Oceania                     7
# Seven seas (open ocean)     1
# Antarctica                  1
# Name: continent, dtype: int64

# %%
africa = world[ world['continent'] == 'Africa']

africa.plot(
    column="name",
    legend=True,
    figsize=(10, 10)
);

# %%
africa.plot(
    column="pop_est", 
    legend=True,
    figsize=(10, 10)
);

# %% [markdown]
# # Explore (Again)

# %%
world.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Augmenting with additional data

# %%
from io import StringIO
# import json

# https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_week.geojson
earthquake_data = """{"type":"FeatureCollection","metadata":{"generated":1663265187000,"url":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/significant_week.geojson","title":"USGS Significant Earthquakes, Past Week","status":200,"api":"1.10.3","count":3},"features":[{"type":"Feature","properties":{"mag":7,"place":"208 km SSE of Isangel, Vanuatu","time":1663153447447,"updated":1663240608063,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us7000i7ya","detail":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000i7ya.geojson","felt":11,"cdi":6.9,"mmi":5.399,"alert":"green","status":"reviewed","tsunami":1,"sig":761,"net":"us","code":"7000i7ya","ids":",at00ri75ev,pt22257002,us7000i7ya,","sources":",at,pt,us,","types":",dyfi,finite-fault,general-text,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,","nst":197,"dmin":2.955,"rms":0.65,"gap":45,"magType":"mww","type":"earthquake","title":"M 7.0 - 208 km SSE of Isangel, Vanuatu"},"geometry":{"type":"Point","coordinates":[170.2397,-21.1908,144.885]},"id":"us7000i7ya"},
{"type":"Feature","properties":{"mag":4.39,"place":"3km N of Santa Rosa, CA","time":1663119578730,"updated":1663264677657,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/nc73781306","detail":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73781306.geojson","felt":6846,"cdi":5.7,"mmi":5.793,"alert":"green","status":"reviewed","tsunami":1,"sig":866,"net":"nc","code":"73781306","ids":",at00ri6fa3,nc73781306,us7000i7tl,ew1663119580,","sources":",at,nc,us,ew,","types":",dyfi,focal-mechanism,impact-link,losspager,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shake-alert,shakemap,","nst":143,"dmin":0.02906,"rms":0.14,"gap":22,"magType":"mw","type":"earthquake","title":"M 4.4 - 3km N of Santa Rosa, CA"},"geometry":{"type":"Point","coordinates":[-122.7071667,38.475,5.57]},"id":"nc73781306"},
{"type":"Feature","properties":{"mag":7.6,"place":"66 km E of Kainantu, Papua New Guinea","time":1662853617827,"updated":1663214344002,"tz":null,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us6000iitd","detail":"https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000iitd.geojson","felt":102,"cdi":7.5,"mmi":7.892,"alert":"yellow","status":"reviewed","tsunami":1,"sig":965,"net":"us","code":"6000iitd","ids":",at00ri0q2b,pt22253002,us6000iitd,","sources":",at,pt,us,","types":",dyfi,general-text,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,","nst":121,"dmin":3.203,"rms":0.79,"gap":18,"magType":"mww","type":"earthquake","title":"M 7.6 - 66 km E of Kainantu, Papua New Guinea"},"geometry":{"type":"Point","coordinates":[146.4692,-6.2557,90.013]},"id":"us6000iitd"}],"bbox":[-122.7071667,-21.1908,5.57,170.2397,38.475,144.885]}"""

# treat string like a file
earthquake_file = StringIO(earthquake_data)

# read file into geopandas
earthquake = gpd.read_file(earthquake_file)

# %%
earthquake.shape
# Out:
# (3, 28)

# %%
earthquake.head()
# Out:
#            id   mag                                  place           time  \
# 0  us7000i7ya  7.00         208 km SSE of Isangel, Vanuatu  1663153447447
# 1  nc73781306  4.39                3km N of Santa Rosa, CA  1663119578730
# 2  us6000iitd  7.60  66 km E of Kainantu, Papua New Guinea  1662853617827
#
#          updated    tz                                                url  \
# 0  1663240608063  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1663264677657  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1663214344002  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi    mmi  \
# 0  https://earthquake.usgs.gov/earthquakes/feed/v...    11  6.9  5.399
# 1  https://earthquake.usgs.gov/earthquakes/feed/v...  6846  5.7  5.793
# 2  https://earthquake.usgs.gov/earthquakes/feed/v...   102  7.5  7.892
#
#     alert    status  tsunami  sig net      code  \
# ...

# %%
m = world.explore()
earthquake.explore(m=m, color="black")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
