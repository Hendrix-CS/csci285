# %%
# %matplotlib inline
import pandas as pd
from plotnine import *

# %%
df = pd.read_csv("data/chickwts.txt", sep="\t")

# %%
df
# Out:
#     weight       feed
# 0      179  horsebean
# 1      160  horsebean
# 2      136  horsebean
# 3      227  horsebean
# 4      217  horsebean
# ..     ...        ...
# 66     359     casein
# 67     216     casein
# 68     222     casein
# 69     283     casein
# 70     332     casein
#
# [71 rows x 2 columns]

# %%
ggplot(df, aes(x="feed", y="weight")) \
+ geom_boxplot()
# Out:
# <ggplot: (312153670)>

# %%
penguin_df = pd.read_csv("data/penguins_raw.csv")

# %%
penguin_df
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %%
ggplot(penguin_df, aes(x="Sex", y="Body Mass (g)")) \
+ geom_boxplot()
# Out:
# <ggplot: (312401734)>

# %%
penguin_df = penguin_df.dropna(subset=["Sex"])

# %%
penguin_df = penguin_df.loc[(penguin_df["Sex"] == "MALE") | (penguin_df["Sex"] == "FEMALE")]

# %%
ggplot(penguin_df, aes(x="Culmen Length (mm)", fill="Sex")) \
+ geom_histogram(bins = 30, position="identity", alpha=0.5)
# Out:
# <ggplot: (312894236)>

# %%
ggplot(penguin_df, aes(y="Culmen Length (mm)", x="Flipper Length (mm)", color="Species")) \
+ geom_point() \
+ geom_smooth(method="lm") \
+ labs(title="Palmer Penguins Flipper and Bill Relationship")
# Out:
# <ggplot: (312352925)>
