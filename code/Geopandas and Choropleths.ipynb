# %%
# %matplotlib inline
import pandas as pd
import geopandas

# %%
world = geopandas.read_file(geopandas.datasets.get_path("naturalearth_lowres"))

# %%
world
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# ...

# %%
world.plot()

# %%
sa = world.loc[world["continent"] == "South America"]

# %%
sa.plot(column="pop_est", cmap="GnBu", figsize=(12, 12))

# %%
na = world.loc[world["continent"] == "North America"]

# %%
na.plot()

# %%
na.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
na = na.to_crs("EPSG:3083")

# %%
na.plot()

# %%
us = geopandas.read_file("data/tl_2017_us_state/tl_2017_us_state.shp")

# %%
us.plot()

# %%
us
# Out:
#    REGION DIVISION STATEFP   STATENS GEOID STUSPS  \
# 0       3        5      54  01779805    54     WV
# 1       3        5      12  00294478    12     FL
# 2       2        3      17  01779784    17     IL
# 3       2        4      27  00662849    27     MN
# 4       3        5      24  01714934    24     MD
# 5       1        1      44  01219835    44     RI
# 6       4        8      16  01779783    16     ID
# 7       1        1      33  01779794    33     NH
# 8       3        5      37  01027616    37     NC
# 9       1        1      50  01779802    50     VT
# 10      1        1      09  01779780    09     CT
# 11      3        5      10  01779781    10     DE
# 12      4        8      35  00897535    35     NM
# 13      4        9      06  01779778    06     CA
# 14      1        2      34  01779795    34     NJ
# 15      2        3      55  01779806    55     WI
# 16      4        9      41  01155107    41     OR
# 17      2        4      31  01779792    31     NE
# ...

# %%
continental = us.loc[us["STUSPS"] != "HI"]

# %%
continental.plot()

# %%
for state in ["HI", "AK", "PR", "VI", "MP", "AS", "GU"]:
    continental = continental.loc[continental["STUSPS"] != state]

# %%
continental = continental.to_crs("EPSG:3083")

# %%
continental.plot(column="ALAND", cmap="GnBu", figsize=(12, 12))

# %%
statepop = pd.read_csv("data/statepop.csv")

# %%
statepop
# Out:
#                    State  2018 Population
# 0             California         39776830
# 1                  Texas         28704330
# 2                Florida         21312211
# 3               New York         19862512
# 4           Pennsylvania         12823989
# 5               Illinois         12768320
# 6                   Ohio         11694664
# 7                Georgia         10545138
# 8         North Carolina         10390149
# 9               Michigan          9991177
# 10            New Jersey          9032872
# 11              Virginia          8525660
# 12            Washington          7530552
# 13               Arizona          7123898
# 14         Massachusetts          6895917
# 15             Tennessee          6782564
# 16               Indiana          6699629
# 17              Missouri          6135888
# 18              Maryland          6079602
# 19             Wisconsin          5818049
# 20              Colorado          5684203
# ...

# %%
continental = continental.join(statepop.set_index("State"), on="NAME")

# %%
continental.plot(column="2018 Population", cmap="GnBu", figsize=(12, 12))

# %%
hawaii = us.loc[us["STUSPS"] == "HI"]

# %%
ax = hawaii.plot(figsize = (12, 12))

# %%
ax = hawaii.plot(figsize = (12, 12))
ax.set_xlim(-162, -154)
ax.set_ylim(18, 24)
# Out:
# (18.0, 24.0)

# %%
pdf = pd.read_csv("data/puffermap.csv")

# %%
pdf
# Out:
#      Latitude   Longitude    Status
# 0   21.434152 -157.789541  Necropsy
# 1   21.430319 -157.815249  Necropsy
# 2   20.689973 -156.439225  Necropsy
# 3   21.285268 -157.841025  Necropsy
# 4   21.309254 -157.889702  Necropsy
# ..        ...         ...       ...
# 90  21.655408 -158.061258   Observe
# 91  21.302958 -157.924454   Observe
# 92  21.291321 -157.662129   Observe
# 93  20.906196 -156.689587   Observe
# 94  21.280874 -157.837701   Observe
#
# [95 rows x 3 columns]

# %%
geopuffer = geopandas.GeoDataFrame(pdf, geometry =
                                   geopandas.points_from_xy(pdf.Longitude, pdf.Latitude))

# %%
geopuffer
# Out:
#      Latitude   Longitude    Status                     geometry
# 0   21.434152 -157.789541  Necropsy  POINT (-157.78954 21.43415)
# 1   21.430319 -157.815249  Necropsy  POINT (-157.81525 21.43032)
# 2   20.689973 -156.439225  Necropsy  POINT (-156.43922 20.68997)
# 3   21.285268 -157.841025  Necropsy  POINT (-157.84103 21.28527)
# 4   21.309254 -157.889702  Necropsy  POINT (-157.88970 21.30925)
# ..        ...         ...       ...                          ...
# 90  21.655408 -158.061258   Observe  POINT (-158.06126 21.65541)
# 91  21.302958 -157.924454   Observe  POINT (-157.92445 21.30296)
# 92  21.291321 -157.662129   Observe  POINT (-157.66213 21.29132)
# 93  20.906196 -156.689587   Observe  POINT (-156.68959 20.90620)
# 94  21.280874 -157.837701   Observe  POINT (-157.83770 21.28087)
#
# [95 rows x 4 columns]

# %%
geopuffer.plot()

# %%
axes2 = hawaii.plot(figsize = (12, 12), facecolor="#00000055", edgecolor="green")
axes2.set_xlim(-162, -154)
axes2.set_ylim(18, 24)
geopuffer.plot(ax = axes2, markersize=5)

# %%
world.plot(column="continent", legend=True, figsize=(14, 14))
